# %% [markdown]
# # Data prep and modeling
#
# The first half of this notebook is basically converting the dictionary of dataframes built in the timeline notebook into train, val, and test sets consisting of tensors of timeframes as their features and tensors of positions as their targets.
#
# The second half is building models (and a custon loss function) and then evaluating them.
#
# Some of the tools here are based on the tensorflow guide on time series - though they were heavily modified.
# https://www.tensorflow.org/tutorials/structured_data/time_series/

# %%
import pickle
import json
import requests
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
np.random.seed(4)

# these are from the keras guide
mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %% [markdown]
# ## preparing the data a bit

# %%
# load the game-dataframe dictionary
dfs_dict = pickle.load(open("../data/timeline-di.p", "rb"))

# %%
# Here I split the dataframe by game. If using the model to predict future clid games, the ids shouldn't be shuffled.
gameids = list(dfs_dict.keys())
np.random.shuffle(gameids)
idcount = len(gameids)
# these can be changed if different sized splits are wanted
# (or remove older games if ids are sorted)
splits = [int(idcount*i) for i in [0,.8,.9,1]]
train_ids = gameids[splits[0]:splits[1]]
val_ids = gameids[splits[1]:splits[2]]
test_ids = gameids[splits[2]:splits[3]]

# %%
# Checking things are working
dfs_dict[train_ids[1]][0:10]
# Out:
#    enemy6currentGold  enemy6totalGold  enemy6level  enemy6jungleMinionsKilled  \
# 0              500.0            500.0          1.0                        0.0
# 1                0.0            500.0          1.0                        0.0
# 2               83.0            583.0          1.0                        0.0
# 3              678.0           1178.0          3.0                        0.0
# 4               79.0           1364.0          3.0                        0.0
# 5              411.0           1696.0          5.0                        0.0
# 6               60.0           2095.0          5.0                        0.0
# 7              301.0           2336.0          6.0                        0.0
# 8              625.0           2660.0          7.0                        0.0
# 9              218.0           2953.0          7.0                        0.0
#
#    enemy6x  enemy6y  enemy7currentGold  enemy7totalGold  enemy7level  \
# 0    351.0    293.0              500.0            500.0          1.0
# 1   6882.0   6193.0                0.0            500.0          1.0
# 2   6210.0   6515.0               97.0            597.0          1.0
# 3   8081.0   6800.0              427.0            927.0          3.0
# 4   5373.0   5570.0              662.0           1162.0          4.0
# 5   7192.0   7922.0               50.0           1550.0          5.0
# 6   2838.0   2296.0              114.0           1764.0          5.0
# 7   6808.0   7439.0              609.0           2259.0          6.0
# 8   8198.0   6693.0              899.0           2549.0          7.0
# 9   6421.0   6660.0              427.0           2877.0          7.0
#
#    enemy7jungleMinionsKilled  ...  ally4jungleMinionsKilled   ally4x   ally4y  \
# 0                        0.0  ...                       0.0  14237.0  14579.0
# 1                        0.0  ...                       0.0   8509.0   5793.0
# 2                        0.0  ...                       0.0  13097.0   2406.0
# 3                        0.0  ...                       0.0  14340.0  14391.0
# 4                        0.0  ...                       0.0  13769.0   4030.0
# 5                        0.0  ...                       0.0  13341.0   2434.0
# 6                        0.0  ...                       0.0  12671.0   2094.0
# 7                        4.0  ...                       0.0  12705.0   3059.0
# 8                        4.0  ...                       0.0  12988.0   3607.0
# 9                        4.0  ...                       0.0  12922.0   2098.0
#
#    ally_side  playercurrentGold  playertotalGold  playerlevel  \
# 0          1                500              500            1
# 1          1                  0              500            1
# 2          1                120              620            2
# 3          1                579             1079            3
# 4          1                758             1258            3
# 5          1               1152             1652            4
# 6          1                 37             1962            4
# 7          1                280             2205            5
# 8          1                657             2582            6
# 9          1                801             2726            6
#
#    playerjungleMinionsKilled  playerx  playery
# 0                          0    14486    14291
# 1                          0     6898     8118
# 2                          4    11453     6775
# 3                         12    12431     2627
# 4                         13    10996     8668
# 5                         23     6601    12746
# 6                         24    13522     7877
# 7                         29    11064     8619
# 8                         40     7533     8352
# 9                         40    12571     6306
#
# [10 rows x 61 columns]

# %%
# test cases that aren't used much anymore
test0 = dfs_dict[train_ids[0]][0:20]
test1 = dfs_dict[train_ids[1]][0:20]
column_indices = {name: i for i, name in enumerate(test0.columns)}

# %% [markdown]
# ## Starting to make classes and functions

# %%
class WindowGenerator():
    """
    This class is heavily based on the tensorflow guide. It allows you
    to create windows from a dataset. Currently a different one needs
    to be called for each window shape, which isn't ideal but is 
    complicated to improve.
    
        Arguments:
    input_width: int of how many time steps back the feature set should
                 include.
                 
    label_width: int of how many time steps the label set should
                 include. This is always 1 for windows meant for models,
                 but windows made for plotting have larger values.
                 
    shift:       Always should be 1 as far as I can tell, indicates
                 how far into the future to predict. 
                 
    eg_df:       Basically just used to get column names but ideally
                 should be removed.
    
    dfdi:        Dictionary of game dataframes, with gameids as index
    
    label_columns: List of the columns of the dfs which are the target.
    
    train_ids, val_ids, and test_ids: Lists of game ids determined earlier.
    
    
    
    """
    def __init__(self, input_width, label_width, shift,
                 eg_df=test0, val_df = test1,
                 dfdi=dfs_dict,
                 train_ids=train_ids,
                 val_ids=val_ids,
                 test_ids=test_ids,
                 label_columns=None):
        
        # Store the dfs etc in the class.
        self.eg_df = eg_df
        self.val_df = val_df
        self.dfdi = dfdi
        
        self.train_ids = train_ids
        self.val_ids = val_ids
        self.test_ids = test_ids
        
        self.trainli = None
        self.valli = None
        self.testli = None

        # Work out the label column indices.
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(eg_df.columns)}

        # Work out the window parameters.
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift

        self.total_window_size = input_width + shift

        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]

        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

    def __repr__(self):
        return '\n'.join([
                f'Total window size: {self.total_window_size}',
                f'Input indices: {self.input_indices}',
                f'Label indices: {self.label_indices}',
                f'Label column name(s): {self.label_columns}'])

# %%
def split_window(self, features):
    """
    Splits window into labels and features.
    
    features: The full data being split. (tensor format I think)
    
    """
    inputs = features[:, self.input_slice, :]
    labels = features[:, self.labels_slice, :]
    if self.label_columns is not None:
        # Stacking the two labels because there's x and y!
        labels = tf.stack(
                [labels[:, :, self.column_indices[name]] for name in self.label_columns],
                axis=-1)
    
    
    # Guide says this, not exactly sure what setting the shapes does exactly:
    # Slicing doesn't preserve static shape information, so set the shapes
    # manually. This way the 'tf.data.Datasets' are easier to inspect.
    inputs.set_shape([None, self.input_width, None])
    labels.set_shape([None, self.label_width, None])

    return inputs, labels

WindowGenerator.split_window = split_window

# %%
def plot_map2(self, model=None, input_width=3, plot_col=["playerx","playery"], max_subplots=3):
    """
    Plots predictions of 3 random windows from the val set of a given model.
    Based very very vaguely on the tensorflow guide.
    
        Arguments:
    model: the model (tf objects only, probably).
    
    input_width: how many time steps the model predicts based on.
    
    plot_col: list of the two columns to predict, probably always the same.
    
    max_subplots: number of windows to plot.
    """
    
    inputs, labels = self.val
    # shuffle indices to get a random window, from
    # https://stackoverflow.com/questions/56575877/shuffling-two-tensors-in-the-same-order
    indices = tf.range(start=0, limit=tf.shape(inputs)[0], dtype=tf.int32)
    shuffled_indices = tf.random.shuffle(indices)
    inputs = tf.gather(inputs, shuffled_indices)
    labels = tf.gather(labels, shuffled_indices)
    
    plt.figure(figsize=(5, 15))
    # get label indices
    plot_col_index = [self.column_indices[plot_col[0]], self.column_indices[plot_col[1]]]
    # an easier way to grab label columns! very fashionable
    xy_inputs = tf.gather(inputs,plot_col_index,axis=2)
    
    # for loop, once for each window
    max_n = min(max_subplots, len(inputs))
    for n in range(max_n):
        plt.subplot(3, 1, n+1)
        plt.xlim(0,15000)
        plt.ylim(0,15000)
        # plot the map background
        img = plt.imread("../data/map.png")
        plt.imshow(img, extent=[0,15000,0,15000],)
        
        # plot each line of the true data as well as labeling them with time
        for i in range(xy_inputs.shape[1]):
            plt.plot(xy_inputs[n, i:i+2, 0], xy_inputs[n, i:i+2, 1], zorder=10, color="blue")#color=(.8-i/10,1-i/8,1-i/8))
            plt.scatter(xy_inputs[n, i, 0], xy_inputs[n, i, 1],
                     marker='${}$'.format(str(i)), s=120, zorder=20, color="white")##color=(.8-i/10,1-i/8,1-i/8))
        
        # vestigial if
        if model is not None:
            # start by predicting each window  
            predictions = []
            for i in range(inputs.shape[1]-1):
                try:
                    current = model.predict(inputs[n,i:i+input_width,:])
                    predictions.append(current[0,:])
                except ValueError:
                    # an attempt to make plotmap work with multistep dense - didn't help
                    predictions = model.predict(tf.expand_dims(inputs[n,:,:],axis=0))
                    predictions = predictions[0,:,:]
                
            # plot line from each prediction to the last true value its based on
            # and keep the time label the same as the previous plotting
            for i in range(len(predictions)-1):
                line_x_0 = predictions[i][0]
                line_x_1 = predictions[i+1][0]
                line_y_0 = predictions[i][1]
                line_y_1 = predictions[i+1][1]
                plt.plot([xy_inputs[n, i+input_width-1, 0],line_x_0],
                         [xy_inputs[n, i+input_width-1, 1], line_y_0], zorder=10, color=(1,0,0))
                plt.scatter(line_x_0, line_y_0, marker='${}$'.format(str(i+input_width)),
                            s=120, zorder=20, color=(1,.8,.5))
        
        # plot the last label abusing i post for loop, very cool
        i=i+1
        plt.scatter(xy_inputs[n, i, 0], xy_inputs[n, i, 1],
                         marker='${}$'.format(str(i)), s=120, zorder=20, color="white")

    
WindowGenerator.plot_map2 = plot_map2

# %%
def make_dataset(self, data, list_me=False):
    """
    make_dataset converts a single game dataframe into windows.
        
        Arguments:
    data: Dataframe of a single game
    
    list_me: Whether to return a list of windows or a map of windows.
    """
    data = np.array(data, dtype=np.float32)
    
    # "Creates a dataset of sliding windows over a timeseries provided as array."
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32,)

    ds = ds.map(self.split_window)
    if list_me:
        return list(ds)
    return ds

WindowGenerator.make_dataset = make_dataset

# %%
def make_split_from_dfdi(self,minmax=(0,20)):
    """
    Combines the windows from each game generated by make_dataset.
        Arguments:
    minmax: Tuple of what timeframe to sample from (minutes).
    """
    # minmax is start and end time of window being sampled from.
    # splits is where the data is being split for train val test split
    if self.dfdi is None:
        print("no dfdi attached")
        raise KeyError("no dfdi attached")
    train_ids = self.train_ids
    val_ids = self.val_ids
    test_ids = self.test_ids
    if self.trainli is None:
        trainli = build_batch(self, self.dfdi, train_ids, minmax)
        train_feats = tf.concat([batch[0] for batch in trainli], axis=0)
        train_labels = tf.concat([batch[1] for batch in trainli], axis=0)
        
    if self.valli is None:
        valli = build_batch(self, self.dfdi, val_ids, minmax)
        val_feats = tf.concat([batch[0] for batch in valli], axis=0)
        val_labels = tf.concat([batch[1] for batch in valli], axis=0)
            
    if self.testli is None:
        testli = build_batch(self, self.dfdi, test_ids, minmax)
        test_feats = tf.concat([batch[0] for batch in testli], axis=0)
        test_labels = tf.concat([batch[1] for batch in testli], axis=0)
            
        
    print(train_feats.shape, train_labels.shape)
    self.train = (train_feats, train_labels)
    self.val = (val_feats, val_labels)
    self.test = (test_feats, test_labels)
    

WindowGenerator.make_split_from_dfdi = make_split_from_dfdi

# %%
def build_batch(self, dfdi, id_li, minmax):
    """
    Calls make_dataset on a specific match and adds it to list. Probably
    doesn't make enough use of self.
    
        Arguments:
    dfdi: dictionary of shape matchid: dataframe.
    
    id_li: list of matchids to use.
    
    minmax: list of start and end time of what times to build from - if game is shorter than max, just uses last time
    returns a list of tf tensors.
    """
    dataset_li = []
    for match_id in id_li:
        df = dfdi[match_id]
        df = df.iloc[minmax[0]:minmax[1]]
        dataset_li = dataset_li + make_dataset(self, data=df, list_me=True)
    return dataset_li

WindowGenerator.build_batch = build_batch

# %% [markdown]
# Check if we've made windows, otherwise making a bunch of windows!

# %%
import pickle

try:
    window_dict = pickle.load(open("../data/windows.p", "rb"))
    
except FileNotFoundError:
    window_dict = {}
    window_sizes = [1,2,3,4,6,8,10]

    for i in window_sizes:
        window_dict[i] = WindowGenerator(
                            input_width = i,
                            label_width = 1,
                            shift = 1,
                            label_columns = ["playerx", "playery"]
        )

    # for plotting
    window_dict["wide_10"] = WindowGenerator(
        input_width=10, label_width=10, shift=1,
        label_columns=["playerx","playery"])

    i=0
    for window in window_dict.values():
        i+=1
        print(i)
        window.make_split_from_dfdi()
        
    pickle.dump(window_dict, open("../data/windows.p","wb"))

# %%
def tensor_distance_mae(y_true, y_pred):
    """takes two [n,1,2] tensors and returns the mean distance between the points"""
    # trying to make it work with lstm but ultimately failed because I can't use
    # sequential model for multitarget lstm.
    if y_true.shape[1:] != y_pred.shape[1:]:
        print(y_true)
        print(y_true[:,:,1])
        print(y_pred)
        #"""
        raise ValueError("passed tensors have different shape "
                         + str(y_true.shape) + " "
                         + str(y_pred.shape) + "\n"
                         + str(y_true) + "\n"
                         + str(y_pred)
                        )
        
    # simple mae calculation
    dx2 = (y_true[:,:,0] - y_pred[:,:,0])**2
    dy2 = (y_true[:,:,1] - y_pred[:,:,1])**2
    dist = (dx2 + dy2)**.5
    dist_sum = tf.math.reduce_mean(dist)
    return dist_sum

# %%
def tensor_distance_rmse(y_true, y_pred):
    """takes two [n,1,2] tensors and returns the root mean squared distance between the points"""
    if y_true.shape[1:] != y_pred.shape[1:]:
        raise ValueError("passed tensors have different shape")
    dx2 = (y_true[:,:,0] - y_pred[:,:,0])**2
    dy2 = (y_true[:,:,1] - y_pred[:,:,1])**2
    dist2 = dx2 + dy2
    dist2_sum = tf.math.reduce_mean(dist2)
    rmse = dist2_sum**.5
    return rmse

# %%
def tensor_distance_log_n(y_true, y_pred, scalar=100):
    """
    takes two [n,1,2] tensors and returns the mean of log(distance/scalar + 1)
    between each predicted and true position.
    """
    # trying to make it work with lstm but ultimately failed because I can't use
    # sequential model for multitarget lstm.
    if y_true.shape[1:] != y_pred.shape[1:]:
        raise ValueError("passed tensors have different shape "
                         + str(y_true.shape) + " "
                         + str(y_pred.shape) + "\n"
                         + str(y_true) + "\n"
                         + str(y_pred)
                        )
        
    # log mae calculation
    dx2 = (y_true[:,:,0] - y_pred[:,:,0])**2
    dy2 = (y_true[:,:,1] - y_pred[:,:,1])**2
    dist = (dx2 + dy2)**.5
    log_dist = tf.math.log(dist/scalar + 1)
    log_dist_mean = tf.math.reduce_mean(log_dist)
    return log_dist_mean

# %%
def tensor_distance_sqrt(y_true, y_pred):
    """
    takes two [n,1,2] tensors and returns the mean of sqrt(distance)
    between each predicted and true position.
    """
    # trying to make it work with lstm but ultimately failed because I can't use
    # sequential model for multitarget lstm.
    if y_true.shape[1:] != y_pred.shape[1:]:
        raise ValueError("passed tensors have different shape "
                         + str(y_true.shape) + " "
                         + str(y_pred.shape) + "\n"
                         + str(y_true) + "\n"
                         + str(y_pred)
                        )
        
    # sqrt mean error calculation
    dx2 = (y_true[:,:,0] - y_pred[:,:,0])**2
    dy2 = (y_true[:,:,1] - y_pred[:,:,1])**2
    root_dist = (dx2 + dy2)**.25
    root_dist_mean = tf.math.reduce_mean(root_dist)
    return root_dist_mean

# %%
# going to use a subset of the conv test set as my test set
train = {}
val = {}
test = {}
train[1] = window_dict[1].train
val[1] = window_dict[1].val
for i in sorted(windows.keys()):
    train[i] = windows[i].train
    val[i] = windows[i].val

# i is largest lookback size
# use largest window's test set as test set for other windows by slicing largest window
test[i] = windows[i].test
for n in range(1,i):
    test[n] = (test[i][0][:,-n:,:], test[i][1])
    display(test[n][0].shape)
# Out:
# TensorShape([320, 1, 61])
# TensorShape([320, 2, 61])
# TensorShape([320, 3, 61])

# %% [markdown]
# ## Building models

# %%
# old baseline class which does very bad
class Baseline(tf.keras.Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index

    def call(self, inputs):
        if self.label_index is None:
            return inputs
        elif isinstance(self.label_index,(list,tuple)):
            return inputs[:,:, self.label_index[0]:self.label_index[1]+1]
        result = inputs[:, :, self.label_index]
        return result[:, :, tf.newaxis]

# %%
baseline = Baseline(label_index=[column_indices["playerx"],column_indices["playery"]])

# %%
linear = tf.keras.Sequential([
    tf.keras.layers.Dense(units=2)
])

# %%
dense = tf.keras.Sequential([
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=2)
])

# %%
# making a model for each lookback
multi_dense_models = {}
#skip first window because its the same as dense effectively
for k in sorted(window_dict.keys())[1:]:
    multi_dense_models[k] = tf.keras.Sequential([
        # Shape: (time, features) => (time*features)
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=32, activation='relu'),
        tf.keras.layers.Dense(units=32, activation='relu'),
        tf.keras.layers.Dense(units=2),
        # Add back the time dimension.
        # Shape: (outputs) => (1, outputs) --- this is from guide's code
        # looks like it might be causing plotting errs -----
        # nvm :( i wish it was the cause
        tf.keras.layers.Reshape([1, -1]),
    ])

# %%
# making a model for each lookback
conv_models = {}
for k in sorted(windows.keys()):
    conv_models[k] = tf.keras.Sequential([
        tf.keras.layers.Conv1D(filters=32,
                               kernel_size=(k),
                               activation='relu'),
        tf.keras.layers.Dense(units=32, activation='relu'),
        tf.keras.layers.Dense(units=2),
    ])

# %%
# lstm model isn't functional yet sob
"""lstm_model = tf.keras.models.Sequential([
    # Shape [batch, time, features] => [batch, time, lstm_units]
    tf.keras.layers.LSTM(32, return_sequences=True),
    # Shape => [batch, time, features]
    tf.keras.layers.Dense(units=2)
])"""
""
# Out:
# ''

# %% [markdown]
# ## Compiling models using custom MAE

# %%
lossli = tensor_distance_log_n #[tensor_distance_mae, tensor_distance_log_n, tensor_distance_sqrt]
metricli = tensor_distance_log_n #[tensor_distance_mae, tensor_distance_log_n, tensor_distance_sqrt]

# %%
baseline.compile(loss=lossli,
                 metrics=metricli)

# %%
linear.compile(loss=lossli,
               metrics=metricli,
               optimizer=tf.optimizers.Adam()
              )
dense.compile(loss=lossli,
               metrics=metricli,
               optimizer=tf.optimizers.Adam()
              )

# %%
for model in multi_dense_models.values():
    model.compile(loss=lossli,
                   metrics=metricli,
                   optimizer=tf.optimizers.Adam()
                  )

# %%
for model in conv_models.values():
    model.compile(loss=lossli,
               metrics=metricli,
               optimizer=tf.optimizers.Adam()
              )
# lstm model isn't functional yet sob
"""lstm_model.compile(loss=tf.losses.MeanSquaredError(),
               metrics=tf.losses.MeanSquaredError(),
               #optimizer=tf.optimizers.Adam()
              )"""
""
# Out:
# ''

# %% [markdown]
# ## Fitting models

# %%
baseline.fit(x=train[1][0],
           y=train[1][1],
           batch_size=32,
           epochs=30,
           verbose=1,
           validation_data=val[1]
          )
# Out:
# Epoch 1/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 2/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 3/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 4/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 5/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 6/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 7/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 8/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 9/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 10/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 11/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 12/30
# 95/95 [==============================] - 0s 975us/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 13/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 14/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 15/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 16/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 17/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 18/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 19/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 20/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 21/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 22/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 23/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 24/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 25/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 26/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 27/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 28/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 29/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867
# Epoch 30/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.9054 - tensor_distance_log_n: 3.9054 - val_loss: 3.8875 - val_tensor_distance_log_n: 3.8867

# %%
linear.fit(x=train[1][0],
           y=train[1][1],
           batch_size=32,
           epochs=30,
           verbose=1,
           validation_data=val[1]
          )
# Out:
# Epoch 1/30
# 95/95 [==============================] - 0s 4ms/step - loss: 4.3936 - tensor_distance_log_n: 4.3936 - val_loss: 3.9393 - val_tensor_distance_log_n: 3.9372
# Epoch 2/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.8650 - tensor_distance_log_n: 3.8650 - val_loss: 3.8934 - val_tensor_distance_log_n: 3.8918
# Epoch 3/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.8394 - tensor_distance_log_n: 3.8394 - val_loss: 3.8608 - val_tensor_distance_log_n: 3.8591
# Epoch 4/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.8142 - tensor_distance_log_n: 3.8142 - val_loss: 3.8443 - val_tensor_distance_log_n: 3.8427
# Epoch 5/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.7934 - tensor_distance_log_n: 3.7934 - val_loss: 3.8193 - val_tensor_distance_log_n: 3.8179
# Epoch 6/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.7734 - tensor_distance_log_n: 3.7734 - val_loss: 3.8292 - val_tensor_distance_log_n: 3.8280
# Epoch 7/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.7549 - tensor_distance_log_n: 3.7549 - val_loss: 3.7755 - val_tensor_distance_log_n: 3.7742
# Epoch 8/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.7460 - tensor_distance_log_n: 3.7460 - val_loss: 3.7660 - val_tensor_distance_log_n: 3.7650
# Epoch 9/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.7309 - tensor_distance_log_n: 3.7309 - val_loss: 3.7410 - val_tensor_distance_log_n: 3.7400
# Epoch 10/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.7248 - tensor_distance_log_n: 3.7248 - val_loss: 3.7259 - val_tensor_distance_log_n: 3.7249
# Epoch 11/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.7132 - tensor_distance_log_n: 3.7132 - val_loss: 3.7176 - val_tensor_distance_log_n: 3.7167
# Epoch 12/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.7094 - tensor_distance_log_n: 3.7094 - val_loss: 3.7008 - val_tensor_distance_log_n: 3.7001
# Epoch 13/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.7018 - tensor_distance_log_n: 3.7018 - val_loss: 3.7247 - val_tensor_distance_log_n: 3.7241
# Epoch 14/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6937 - tensor_distance_log_n: 3.6937 - val_loss: 3.6961 - val_tensor_distance_log_n: 3.6954
# Epoch 15/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6859 - tensor_distance_log_n: 3.6859 - val_loss: 3.6827 - val_tensor_distance_log_n: 3.6821
# Epoch 16/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6796 - tensor_distance_log_n: 3.6796 - val_loss: 3.6935 - val_tensor_distance_log_n: 3.6930
# Epoch 17/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6791 - tensor_distance_log_n: 3.6791 - val_loss: 3.6812 - val_tensor_distance_log_n: 3.6807
# Epoch 18/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6672 - tensor_distance_log_n: 3.6672 - val_loss: 3.6612 - val_tensor_distance_log_n: 3.6605
# Epoch 19/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6658 - tensor_distance_log_n: 3.6658 - val_loss: 3.6843 - val_tensor_distance_log_n: 3.6840
# Epoch 20/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6638 - tensor_distance_log_n: 3.6638 - val_loss: 3.6925 - val_tensor_distance_log_n: 3.6923
# Epoch 21/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6640 - tensor_distance_log_n: 3.6640 - val_loss: 3.6970 - val_tensor_distance_log_n: 3.6967
# Epoch 22/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6593 - tensor_distance_log_n: 3.6593 - val_loss: 3.6491 - val_tensor_distance_log_n: 3.6486
# Epoch 23/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6596 - tensor_distance_log_n: 3.6596 - val_loss: 3.6478 - val_tensor_distance_log_n: 3.6473
# Epoch 24/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6559 - tensor_distance_log_n: 3.6559 - val_loss: 3.6537 - val_tensor_distance_log_n: 3.6533
# Epoch 25/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6492 - tensor_distance_log_n: 3.6492 - val_loss: 3.6401 - val_tensor_distance_log_n: 3.6397
# Epoch 26/30
# 95/95 [==============================] - 0s 1ms/step - loss: 3.6493 - tensor_distance_log_n: 3.6493 - val_loss: 3.6390 - val_tensor_distance_log_n: 3.6385
# Epoch 27/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6460 - tensor_distance_log_n: 3.6460 - val_loss: 3.6519 - val_tensor_distance_log_n: 3.6517
# Epoch 28/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6476 - tensor_distance_log_n: 3.6476 - val_loss: 3.6577 - val_tensor_distance_log_n: 3.6576
# Epoch 29/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6461 - tensor_distance_log_n: 3.6461 - val_loss: 3.6473 - val_tensor_distance_log_n: 3.6471
# Epoch 30/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6388 - tensor_distance_log_n: 3.6388 - val_loss: 3.6351 - val_tensor_distance_log_n: 3.6348

# %%
dense.fit(x=train[1][0],
           y=train[1][1],
           batch_size=32,
           epochs=30,
           verbose=1,
           validation_data=val[1]
          )
# Out:
# Epoch 1/30
# 95/95 [==============================] - 1s 6ms/step - loss: 3.7998 - tensor_distance_log_n: 3.7998 - val_loss: 3.6748 - val_tensor_distance_log_n: 3.6750
# Epoch 2/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.6468 - tensor_distance_log_n: 3.6468 - val_loss: 3.6315 - val_tensor_distance_log_n: 3.6311
# Epoch 3/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6437 - tensor_distance_log_n: 3.6437 - val_loss: 3.6445 - val_tensor_distance_log_n: 3.6445
# Epoch 4/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.6290 - tensor_distance_log_n: 3.6290 - val_loss: 3.6157 - val_tensor_distance_log_n: 3.6160
# Epoch 5/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6153 - tensor_distance_log_n: 3.6153 - val_loss: 3.5891 - val_tensor_distance_log_n: 3.5884
# Epoch 6/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6148 - tensor_distance_log_n: 3.6148 - val_loss: 3.6382 - val_tensor_distance_log_n: 3.6380
# Epoch 7/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.6158 - tensor_distance_log_n: 3.6158 - val_loss: 3.5957 - val_tensor_distance_log_n: 3.5953
# Epoch 8/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.6083 - tensor_distance_log_n: 3.6083 - val_loss: 3.6238 - val_tensor_distance_log_n: 3.6235
# Epoch 9/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5972 - tensor_distance_log_n: 3.5972 - val_loss: 3.6093 - val_tensor_distance_log_n: 3.6085
# Epoch 10/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6043 - tensor_distance_log_n: 3.6043 - val_loss: 3.6486 - val_tensor_distance_log_n: 3.6482
# Epoch 11/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5855 - tensor_distance_log_n: 3.5855 - val_loss: 3.6166 - val_tensor_distance_log_n: 3.6164
# Epoch 12/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5921 - tensor_distance_log_n: 3.5921 - val_loss: 3.6505 - val_tensor_distance_log_n: 3.6490
# Epoch 13/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5920 - tensor_distance_log_n: 3.5920 - val_loss: 3.6232 - val_tensor_distance_log_n: 3.6221
# Epoch 14/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5813 - tensor_distance_log_n: 3.5813 - val_loss: 3.6184 - val_tensor_distance_log_n: 3.6178
# Epoch 15/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5671 - tensor_distance_log_n: 3.5671 - val_loss: 3.6458 - val_tensor_distance_log_n: 3.6457
# Epoch 16/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.5640 - tensor_distance_log_n: 3.5640 - val_loss: 3.6330 - val_tensor_distance_log_n: 3.6327
# Epoch 17/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.5717 - tensor_distance_log_n: 3.5717 - val_loss: 3.6515 - val_tensor_distance_log_n: 3.6513
# Epoch 18/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5700 - tensor_distance_log_n: 3.5700 - val_loss: 3.6546 - val_tensor_distance_log_n: 3.6539
# Epoch 19/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.5558 - tensor_distance_log_n: 3.5558 - val_loss: 3.6245 - val_tensor_distance_log_n: 3.6239
# Epoch 20/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5658 - tensor_distance_log_n: 3.5658 - val_loss: 3.6042 - val_tensor_distance_log_n: 3.6040
# Epoch 21/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5431 - tensor_distance_log_n: 3.5431 - val_loss: 3.6128 - val_tensor_distance_log_n: 3.6127
# Epoch 22/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5310 - tensor_distance_log_n: 3.5310 - val_loss: 3.6397 - val_tensor_distance_log_n: 3.6394
# Epoch 23/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5299 - tensor_distance_log_n: 3.5299 - val_loss: 3.6504 - val_tensor_distance_log_n: 3.6507
# Epoch 24/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5230 - tensor_distance_log_n: 3.5230 - val_loss: 3.6249 - val_tensor_distance_log_n: 3.6247
# Epoch 25/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5298 - tensor_distance_log_n: 3.5298 - val_loss: 3.6251 - val_tensor_distance_log_n: 3.6249
# Epoch 26/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5365 - tensor_distance_log_n: 3.5365 - val_loss: 3.6786 - val_tensor_distance_log_n: 3.6790
# Epoch 27/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.5224 - tensor_distance_log_n: 3.5224 - val_loss: 3.6530 - val_tensor_distance_log_n: 3.6532
# Epoch 28/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5161 - tensor_distance_log_n: 3.5161 - val_loss: 3.6419 - val_tensor_distance_log_n: 3.6408
# Epoch 29/30
# 95/95 [==============================] - 0s 2ms/step - loss: 3.5212 - tensor_distance_log_n: 3.5212 - val_loss: 3.6328 - val_tensor_distance_log_n: 3.6324
# Epoch 30/30
# 95/95 [==============================] - 0s 3ms/step - loss: 3.5087 - tensor_distance_log_n: 3.5087 - val_loss: 3.6787 - val_tensor_distance_log_n: 3.6784

# %%
for width in multi_dense_models.keys():
    multi_dense_models[width].fit(x=train[width][0],
           y=train[width][1],
           batch_size=32,
           epochs=30,
           verbose=1,
           validation_data=val[width]
          )
# Out:
# Epoch 1/30
# 90/90 [==============================] - 0s 5ms/step - loss: 3.7721 - tensor_distance_log_n: 3.7721 - val_loss: 3.5992 - val_tensor_distance_log_n: 3.5869
# Epoch 2/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.6731 - tensor_distance_log_n: 3.6731 - val_loss: 3.6176 - val_tensor_distance_log_n: 3.6130
# Epoch 3/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.6664 - tensor_distance_log_n: 3.6664 - val_loss: 3.6122 - val_tensor_distance_log_n: 3.6079
# Epoch 4/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.6456 - tensor_distance_log_n: 3.6456 - val_loss: 3.6043 - val_tensor_distance_log_n: 3.6016
# Epoch 5/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6331 - tensor_distance_log_n: 3.6331 - val_loss: 3.6164 - val_tensor_distance_log_n: 3.6195
# Epoch 6/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6158 - tensor_distance_log_n: 3.6158 - val_loss: 3.6026 - val_tensor_distance_log_n: 3.6077
# Epoch 7/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6292 - tensor_distance_log_n: 3.6292 - val_loss: 3.5800 - val_tensor_distance_log_n: 3.5848
# Epoch 8/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.6029 - tensor_distance_log_n: 3.6029 - val_loss: 3.5881 - val_tensor_distance_log_n: 3.5934
# Epoch 9/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6026 - tensor_distance_log_n: 3.6026 - val_loss: 3.5767 - val_tensor_distance_log_n: 3.5807
# Epoch 10/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5900 - tensor_distance_log_n: 3.5900 - val_loss: 3.5725 - val_tensor_distance_log_n: 3.5776
# Epoch 11/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5955 - tensor_distance_log_n: 3.5955 - val_loss: 3.5596 - val_tensor_distance_log_n: 3.5629
# Epoch 12/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5807 - tensor_distance_log_n: 3.5807 - val_loss: 3.6053 - val_tensor_distance_log_n: 3.6093
# Epoch 13/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5875 - tensor_distance_log_n: 3.5875 - val_loss: 3.5686 - val_tensor_distance_log_n: 3.5716
# Epoch 14/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5782 - tensor_distance_log_n: 3.5782 - val_loss: 3.5939 - val_tensor_distance_log_n: 3.5930
# Epoch 15/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5782 - tensor_distance_log_n: 3.5782 - val_loss: 3.5624 - val_tensor_distance_log_n: 3.5682
# Epoch 16/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5719 - tensor_distance_log_n: 3.5719 - val_loss: 3.5601 - val_tensor_distance_log_n: 3.5671
# Epoch 17/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5623 - tensor_distance_log_n: 3.5623 - val_loss: 3.5620 - val_tensor_distance_log_n: 3.5656
# Epoch 18/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5620 - tensor_distance_log_n: 3.5620 - val_loss: 3.5523 - val_tensor_distance_log_n: 3.5587
# Epoch 19/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5676 - tensor_distance_log_n: 3.5676 - val_loss: 3.5556 - val_tensor_distance_log_n: 3.5646
# Epoch 20/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5576 - tensor_distance_log_n: 3.5576 - val_loss: 3.5941 - val_tensor_distance_log_n: 3.5995
# Epoch 21/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5614 - tensor_distance_log_n: 3.5614 - val_loss: 3.5642 - val_tensor_distance_log_n: 3.5691
# Epoch 22/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5519 - tensor_distance_log_n: 3.5519 - val_loss: 3.5755 - val_tensor_distance_log_n: 3.5816
# Epoch 23/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5574 - tensor_distance_log_n: 3.5574 - val_loss: 3.5563 - val_tensor_distance_log_n: 3.5646
# Epoch 24/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5485 - tensor_distance_log_n: 3.5485 - val_loss: 3.5413 - val_tensor_distance_log_n: 3.5538
# Epoch 25/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5446 - tensor_distance_log_n: 3.5446 - val_loss: 3.5529 - val_tensor_distance_log_n: 3.5631
# Epoch 26/30
# 90/90 [==============================] - 0s 1ms/step - loss: 3.5438 - tensor_distance_log_n: 3.5438 - val_loss: 3.5682 - val_tensor_distance_log_n: 3.5783
# Epoch 27/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5439 - tensor_distance_log_n: 3.5439 - val_loss: 3.5521 - val_tensor_distance_log_n: 3.5601
# Epoch 28/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5540 - tensor_distance_log_n: 3.5540 - val_loss: 3.5551 - val_tensor_distance_log_n: 3.5635
# Epoch 29/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5433 - tensor_distance_log_n: 3.5433 - val_loss: 3.5839 - val_tensor_distance_log_n: 3.5891
# Epoch 30/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5409 - tensor_distance_log_n: 3.5409 - val_loss: 3.5605 - val_tensor_distance_log_n: 3.5697
# Epoch 1/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.7790 - tensor_distance_log_n: 3.7790 - val_loss: 3.6441 - val_tensor_distance_log_n: 3.6437
# Epoch 2/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6813 - tensor_distance_log_n: 3.6813 - val_loss: 3.6952 - val_tensor_distance_log_n: 3.6899
# Epoch 3/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6591 - tensor_distance_log_n: 3.6591 - val_loss: 3.5956 - val_tensor_distance_log_n: 3.5940
# Epoch 4/30
# 85/85 [==============================] - 0s 4ms/step - loss: 3.6470 - tensor_distance_log_n: 3.6470 - val_loss: 3.6001 - val_tensor_distance_log_n: 3.5972
# Epoch 5/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.6402 - tensor_distance_log_n: 3.6402 - val_loss: 3.6591 - val_tensor_distance_log_n: 3.6561
# Epoch 6/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6282 - tensor_distance_log_n: 3.6282 - val_loss: 3.5927 - val_tensor_distance_log_n: 3.5875
# Epoch 7/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.6264 - tensor_distance_log_n: 3.6264 - val_loss: 3.6511 - val_tensor_distance_log_n: 3.6479
# Epoch 8/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6264 - tensor_distance_log_n: 3.6264 - val_loss: 3.6210 - val_tensor_distance_log_n: 3.6203
# Epoch 9/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.6178 - tensor_distance_log_n: 3.6178 - val_loss: 3.6084 - val_tensor_distance_log_n: 3.6039
# Epoch 10/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6107 - tensor_distance_log_n: 3.6107 - val_loss: 3.6287 - val_tensor_distance_log_n: 3.6237
# Epoch 11/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6081 - tensor_distance_log_n: 3.6081 - val_loss: 3.6112 - val_tensor_distance_log_n: 3.6056
# Epoch 12/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6063 - tensor_distance_log_n: 3.6063 - val_loss: 3.5749 - val_tensor_distance_log_n: 3.5708
# Epoch 13/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5925 - tensor_distance_log_n: 3.5925 - val_loss: 3.6200 - val_tensor_distance_log_n: 3.6167
# Epoch 14/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5951 - tensor_distance_log_n: 3.5951 - val_loss: 3.6309 - val_tensor_distance_log_n: 3.6256
# Epoch 15/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5945 - tensor_distance_log_n: 3.5945 - val_loss: 3.6335 - val_tensor_distance_log_n: 3.6274
# Epoch 16/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5860 - tensor_distance_log_n: 3.5860 - val_loss: 3.6034 - val_tensor_distance_log_n: 3.5976
# Epoch 17/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5759 - tensor_distance_log_n: 3.5759 - val_loss: 3.6151 - val_tensor_distance_log_n: 3.6119
# Epoch 18/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5788 - tensor_distance_log_n: 3.5788 - val_loss: 3.5773 - val_tensor_distance_log_n: 3.5718
# Epoch 19/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.5719 - tensor_distance_log_n: 3.5719 - val_loss: 3.5944 - val_tensor_distance_log_n: 3.5881
# Epoch 20/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5688 - tensor_distance_log_n: 3.5688 - val_loss: 3.5771 - val_tensor_distance_log_n: 3.5724
# Epoch 21/30
# 85/85 [==============================] - 0s 1ms/step - loss: 3.5656 - tensor_distance_log_n: 3.5656 - val_loss: 3.5881 - val_tensor_distance_log_n: 3.5842
# Epoch 22/30
# 85/85 [==============================] - 0s 1ms/step - loss: 3.5521 - tensor_distance_log_n: 3.5521 - val_loss: 3.6053 - val_tensor_distance_log_n: 3.6018
# Epoch 23/30
# 85/85 [==============================] - 0s 1ms/step - loss: 3.5612 - tensor_distance_log_n: 3.5612 - val_loss: 3.5740 - val_tensor_distance_log_n: 3.5699
# Epoch 24/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5374 - tensor_distance_log_n: 3.5374 - val_loss: 3.5895 - val_tensor_distance_log_n: 3.5858
# Epoch 25/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5519 - tensor_distance_log_n: 3.5519 - val_loss: 3.5759 - val_tensor_distance_log_n: 3.5711
# Epoch 26/30
# 85/85 [==============================] - 0s 1ms/step - loss: 3.5433 - tensor_distance_log_n: 3.5433 - val_loss: 3.5876 - val_tensor_distance_log_n: 3.5825
# Epoch 27/30
# 85/85 [==============================] - 0s 1ms/step - loss: 3.5416 - tensor_distance_log_n: 3.5416 - val_loss: 3.5799 - val_tensor_distance_log_n: 3.5766
# Epoch 28/30
# 85/85 [==============================] - 0s 1ms/step - loss: 3.5460 - tensor_distance_log_n: 3.5460 - val_loss: 3.6232 - val_tensor_distance_log_n: 3.6236
# Epoch 29/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5254 - tensor_distance_log_n: 3.5254 - val_loss: 3.5939 - val_tensor_distance_log_n: 3.5898
# Epoch 30/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5250 - tensor_distance_log_n: 3.5250 - val_loss: 3.5890 - val_tensor_distance_log_n: 3.5848
# Epoch 1/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.7627 - tensor_distance_log_n: 3.7627 - val_loss: 3.6520 - val_tensor_distance_log_n: 3.6520
# Epoch 2/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6837 - tensor_distance_log_n: 3.6837 - val_loss: 3.6319 - val_tensor_distance_log_n: 3.6319
# Epoch 3/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.6617 - tensor_distance_log_n: 3.6617 - val_loss: 3.6152 - val_tensor_distance_log_n: 3.6152
# Epoch 4/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6520 - tensor_distance_log_n: 3.6520 - val_loss: 3.6134 - val_tensor_distance_log_n: 3.6134
# Epoch 5/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6453 - tensor_distance_log_n: 3.6453 - val_loss: 3.6377 - val_tensor_distance_log_n: 3.6377
# Epoch 6/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6409 - tensor_distance_log_n: 3.6409 - val_loss: 3.6329 - val_tensor_distance_log_n: 3.6329
# Epoch 7/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6270 - tensor_distance_log_n: 3.6270 - val_loss: 3.6169 - val_tensor_distance_log_n: 3.6169
# Epoch 8/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.6214 - tensor_distance_log_n: 3.6214 - val_loss: 3.5918 - val_tensor_distance_log_n: 3.5918
# Epoch 9/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.6222 - tensor_distance_log_n: 3.6222 - val_loss: 3.6022 - val_tensor_distance_log_n: 3.6022
# Epoch 10/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6210 - tensor_distance_log_n: 3.6210 - val_loss: 3.5844 - val_tensor_distance_log_n: 3.5844
# Epoch 11/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6019 - tensor_distance_log_n: 3.6019 - val_loss: 3.5850 - val_tensor_distance_log_n: 3.5850
# Epoch 12/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6088 - tensor_distance_log_n: 3.6088 - val_loss: 3.6080 - val_tensor_distance_log_n: 3.6080
# Epoch 13/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.6030 - tensor_distance_log_n: 3.6030 - val_loss: 3.6100 - val_tensor_distance_log_n: 3.6100
# Epoch 14/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6107 - tensor_distance_log_n: 3.6107 - val_loss: 3.5806 - val_tensor_distance_log_n: 3.5806
# Epoch 15/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.5950 - tensor_distance_log_n: 3.5950 - val_loss: 3.5965 - val_tensor_distance_log_n: 3.5965
# Epoch 16/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.5844 - tensor_distance_log_n: 3.5844 - val_loss: 3.6055 - val_tensor_distance_log_n: 3.6055
# Epoch 17/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.5914 - tensor_distance_log_n: 3.5914 - val_loss: 3.6358 - val_tensor_distance_log_n: 3.6358
# Epoch 18/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.5786 - tensor_distance_log_n: 3.5786 - val_loss: 3.5764 - val_tensor_distance_log_n: 3.5764
# Epoch 19/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.5887 - tensor_distance_log_n: 3.5887 - val_loss: 3.5872 - val_tensor_distance_log_n: 3.5872
# Epoch 20/30
# 80/80 [==============================] - ETA: 0s - loss: 3.5728 - tensor_distance_log_n: 3.572 - 0s 2ms/step - loss: 3.5721 - tensor_distance_log_n: 3.5721 - val_loss: 3.5753 - val_tensor_distance_log_n: 3.5753
# Epoch 21/30
# 80/80 [==============================] - 0s 4ms/step - loss: 3.5830 - tensor_distance_log_n: 3.5830 - val_loss: 3.5756 - val_tensor_distance_log_n: 3.5756
# Epoch 22/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5616 - tensor_distance_log_n: 3.5616 - val_loss: 3.5763 - val_tensor_distance_log_n: 3.5763
# Epoch 23/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5577 - tensor_distance_log_n: 3.5577 - val_loss: 3.6144 - val_tensor_distance_log_n: 3.6144
# Epoch 24/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5439 - tensor_distance_log_n: 3.5439 - val_loss: 3.5837 - val_tensor_distance_log_n: 3.5837
# Epoch 25/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5615 - tensor_distance_log_n: 3.5615 - val_loss: 3.6060 - val_tensor_distance_log_n: 3.6060
# Epoch 26/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.5569 - tensor_distance_log_n: 3.5569 - val_loss: 3.6070 - val_tensor_distance_log_n: 3.6070
# Epoch 27/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5413 - tensor_distance_log_n: 3.5413 - val_loss: 3.5954 - val_tensor_distance_log_n: 3.5954
# Epoch 28/30
# 80/80 [==============================] - 0s 1ms/step - loss: 3.5474 - tensor_distance_log_n: 3.5474 - val_loss: 3.5897 - val_tensor_distance_log_n: 3.5897
# Epoch 29/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5294 - tensor_distance_log_n: 3.5294 - val_loss: 3.6016 - val_tensor_distance_log_n: 3.6016
# Epoch 30/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5516 - tensor_distance_log_n: 3.5516 - val_loss: 3.5840 - val_tensor_distance_log_n: 3.5840

# %%
for width in conv_models.keys():
    conv_models[width].fit(x=train[width][0],
           y=train[width][1],
           batch_size=32,
           epochs=30,
           verbose=1,
           validation_data=val[width]
          )
# Out:
# Epoch 1/30
# 90/90 [==============================] - 0s 5ms/step - loss: 3.7832 - tensor_distance_log_n: 3.7832 - val_loss: 3.6154 - val_tensor_distance_log_n: 3.6252
# Epoch 2/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6634 - tensor_distance_log_n: 3.6634 - val_loss: 3.6169 - val_tensor_distance_log_n: 3.6307
# Epoch 3/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6405 - tensor_distance_log_n: 3.6405 - val_loss: 3.6112 - val_tensor_distance_log_n: 3.6165
# Epoch 4/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6310 - tensor_distance_log_n: 3.6310 - val_loss: 3.5852 - val_tensor_distance_log_n: 3.5893
# Epoch 5/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6251 - tensor_distance_log_n: 3.6251 - val_loss: 3.5836 - val_tensor_distance_log_n: 3.5867
# Epoch 6/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6169 - tensor_distance_log_n: 3.6169 - val_loss: 3.6014 - val_tensor_distance_log_n: 3.6131
# Epoch 7/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6081 - tensor_distance_log_n: 3.6081 - val_loss: 3.5850 - val_tensor_distance_log_n: 3.5840
# Epoch 8/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.6113 - tensor_distance_log_n: 3.6113 - val_loss: 3.5761 - val_tensor_distance_log_n: 3.5794
# Epoch 9/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5944 - tensor_distance_log_n: 3.5944 - val_loss: 3.5812 - val_tensor_distance_log_n: 3.5797
# Epoch 10/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5946 - tensor_distance_log_n: 3.5946 - val_loss: 3.5740 - val_tensor_distance_log_n: 3.5743
# Epoch 11/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5959 - tensor_distance_log_n: 3.5959 - val_loss: 3.5906 - val_tensor_distance_log_n: 3.5960
# Epoch 12/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5833 - tensor_distance_log_n: 3.5833 - val_loss: 3.5542 - val_tensor_distance_log_n: 3.5578
# Epoch 13/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5844 - tensor_distance_log_n: 3.5844 - val_loss: 3.5789 - val_tensor_distance_log_n: 3.5823
# Epoch 14/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5843 - tensor_distance_log_n: 3.5843 - val_loss: 3.6189 - val_tensor_distance_log_n: 3.6253
# Epoch 15/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5824 - tensor_distance_log_n: 3.5824 - val_loss: 3.5627 - val_tensor_distance_log_n: 3.5699
# Epoch 16/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5740 - tensor_distance_log_n: 3.5740 - val_loss: 3.5742 - val_tensor_distance_log_n: 3.5890
# Epoch 17/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5821 - tensor_distance_log_n: 3.5821 - val_loss: 3.5766 - val_tensor_distance_log_n: 3.5719
# Epoch 18/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5644 - tensor_distance_log_n: 3.5644 - val_loss: 3.5594 - val_tensor_distance_log_n: 3.5729
# Epoch 19/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5632 - tensor_distance_log_n: 3.5632 - val_loss: 3.5709 - val_tensor_distance_log_n: 3.5835
# Epoch 20/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5648 - tensor_distance_log_n: 3.5648 - val_loss: 3.5553 - val_tensor_distance_log_n: 3.5696
# Epoch 21/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5609 - tensor_distance_log_n: 3.5609 - val_loss: 3.5634 - val_tensor_distance_log_n: 3.5747
# Epoch 22/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5714 - tensor_distance_log_n: 3.5714 - val_loss: 3.5716 - val_tensor_distance_log_n: 3.5816
# Epoch 23/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5593 - tensor_distance_log_n: 3.5593 - val_loss: 3.5578 - val_tensor_distance_log_n: 3.5669
# Epoch 24/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5498 - tensor_distance_log_n: 3.5498 - val_loss: 3.5715 - val_tensor_distance_log_n: 3.5783
# Epoch 25/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5611 - tensor_distance_log_n: 3.5611 - val_loss: 3.5627 - val_tensor_distance_log_n: 3.5708
# Epoch 26/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5430 - tensor_distance_log_n: 3.5430 - val_loss: 3.5627 - val_tensor_distance_log_n: 3.5711
# Epoch 27/30
# 90/90 [==============================] - 0s 3ms/step - loss: 3.5389 - tensor_distance_log_n: 3.5389 - val_loss: 3.5764 - val_tensor_distance_log_n: 3.5832
# Epoch 28/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5301 - tensor_distance_log_n: 3.5301 - val_loss: 3.5820 - val_tensor_distance_log_n: 3.5880
# Epoch 29/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5361 - tensor_distance_log_n: 3.5361 - val_loss: 3.5848 - val_tensor_distance_log_n: 3.5957
# Epoch 30/30
# 90/90 [==============================] - 0s 2ms/step - loss: 3.5371 - tensor_distance_log_n: 3.5371 - val_loss: 3.5841 - val_tensor_distance_log_n: 3.5943
# Epoch 1/30
# 85/85 [==============================] - 1s 6ms/step - loss: 3.7641 - tensor_distance_log_n: 3.7641 - val_loss: 3.6958 - val_tensor_distance_log_n: 3.6965
# Epoch 2/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.6713 - tensor_distance_log_n: 3.6713 - val_loss: 3.6594 - val_tensor_distance_log_n: 3.6526
# Epoch 3/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6647 - tensor_distance_log_n: 3.6647 - val_loss: 3.6208 - val_tensor_distance_log_n: 3.6200
# Epoch 4/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6457 - tensor_distance_log_n: 3.6457 - val_loss: 3.6106 - val_tensor_distance_log_n: 3.6098
# Epoch 5/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6387 - tensor_distance_log_n: 3.6387 - val_loss: 3.6166 - val_tensor_distance_log_n: 3.6173
# Epoch 6/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6263 - tensor_distance_log_n: 3.6263 - val_loss: 3.6420 - val_tensor_distance_log_n: 3.6419
# Epoch 7/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6266 - tensor_distance_log_n: 3.6266 - val_loss: 3.5981 - val_tensor_distance_log_n: 3.5999
# Epoch 8/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6256 - tensor_distance_log_n: 3.6256 - val_loss: 3.6610 - val_tensor_distance_log_n: 3.6609
# Epoch 9/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6253 - tensor_distance_log_n: 3.6253 - val_loss: 3.5859 - val_tensor_distance_log_n: 3.5829
# Epoch 10/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6220 - tensor_distance_log_n: 3.6220 - val_loss: 3.6594 - val_tensor_distance_log_n: 3.6609
# Epoch 11/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.6153 - tensor_distance_log_n: 3.6153 - val_loss: 3.6107 - val_tensor_distance_log_n: 3.6087
# Epoch 12/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6175 - tensor_distance_log_n: 3.6175 - val_loss: 3.6420 - val_tensor_distance_log_n: 3.6408
# Epoch 13/30
# 85/85 [==============================] - 0s 4ms/step - loss: 3.6047 - tensor_distance_log_n: 3.6047 - val_loss: 3.5850 - val_tensor_distance_log_n: 3.5830
# Epoch 14/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.6050 - tensor_distance_log_n: 3.6050 - val_loss: 3.6466 - val_tensor_distance_log_n: 3.6453
# Epoch 15/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.6077 - tensor_distance_log_n: 3.6077 - val_loss: 3.5754 - val_tensor_distance_log_n: 3.5736
# Epoch 16/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5905 - tensor_distance_log_n: 3.5905 - val_loss: 3.5895 - val_tensor_distance_log_n: 3.5889
# Epoch 17/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5913 - tensor_distance_log_n: 3.5913 - val_loss: 3.5908 - val_tensor_distance_log_n: 3.5911
# Epoch 18/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.6023 - tensor_distance_log_n: 3.6023 - val_loss: 3.5992 - val_tensor_distance_log_n: 3.5965
# Epoch 19/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5911 - tensor_distance_log_n: 3.5911 - val_loss: 3.5646 - val_tensor_distance_log_n: 3.5619
# Epoch 20/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.5911 - tensor_distance_log_n: 3.5911 - val_loss: 3.6166 - val_tensor_distance_log_n: 3.6156
# Epoch 21/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5900 - tensor_distance_log_n: 3.5900 - val_loss: 3.5659 - val_tensor_distance_log_n: 3.5636
# Epoch 22/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.5799 - tensor_distance_log_n: 3.5799 - val_loss: 3.6045 - val_tensor_distance_log_n: 3.6082
# Epoch 23/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.5743 - tensor_distance_log_n: 3.5743 - val_loss: 3.5678 - val_tensor_distance_log_n: 3.5649
# Epoch 24/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5799 - tensor_distance_log_n: 3.5799 - val_loss: 3.5608 - val_tensor_distance_log_n: 3.5561
# Epoch 25/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5709 - tensor_distance_log_n: 3.5709 - val_loss: 3.6090 - val_tensor_distance_log_n: 3.6064
# Epoch 26/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5800 - tensor_distance_log_n: 3.5800 - val_loss: 3.5704 - val_tensor_distance_log_n: 3.5703
# Epoch 27/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5584 - tensor_distance_log_n: 3.5584 - val_loss: 3.5734 - val_tensor_distance_log_n: 3.5731
# Epoch 28/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5558 - tensor_distance_log_n: 3.5558 - val_loss: 3.5631 - val_tensor_distance_log_n: 3.5620
# Epoch 29/30
# 85/85 [==============================] - 0s 2ms/step - loss: 3.5587 - tensor_distance_log_n: 3.5587 - val_loss: 3.6127 - val_tensor_distance_log_n: 3.6138
# Epoch 30/30
# 85/85 [==============================] - 0s 3ms/step - loss: 3.5628 - tensor_distance_log_n: 3.5628 - val_loss: 3.5850 - val_tensor_distance_log_n: 3.5847
# Epoch 1/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.8132 - tensor_distance_log_n: 3.8132 - val_loss: 3.6780 - val_tensor_distance_log_n: 3.6780
# Epoch 2/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6894 - tensor_distance_log_n: 3.6894 - val_loss: 3.7007 - val_tensor_distance_log_n: 3.7007
# Epoch 3/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6597 - tensor_distance_log_n: 3.6597 - val_loss: 3.6281 - val_tensor_distance_log_n: 3.6281
# Epoch 4/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6764 - tensor_distance_log_n: 3.6764 - val_loss: 3.6187 - val_tensor_distance_log_n: 3.6187
# Epoch 5/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6384 - tensor_distance_log_n: 3.6384 - val_loss: 3.6671 - val_tensor_distance_log_n: 3.6671
# Epoch 6/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6267 - tensor_distance_log_n: 3.6267 - val_loss: 3.6325 - val_tensor_distance_log_n: 3.6325
# Epoch 7/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.6221 - tensor_distance_log_n: 3.6221 - val_loss: 3.6082 - val_tensor_distance_log_n: 3.6082
# Epoch 8/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6251 - tensor_distance_log_n: 3.6251 - val_loss: 3.6059 - val_tensor_distance_log_n: 3.6059
# Epoch 9/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.6284 - tensor_distance_log_n: 3.6284 - val_loss: 3.6248 - val_tensor_distance_log_n: 3.6248
# Epoch 10/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6013 - tensor_distance_log_n: 3.6013 - val_loss: 3.5937 - val_tensor_distance_log_n: 3.5937
# Epoch 11/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6209 - tensor_distance_log_n: 3.6209 - val_loss: 3.6272 - val_tensor_distance_log_n: 3.6272
# Epoch 12/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5966 - tensor_distance_log_n: 3.5966 - val_loss: 3.6157 - val_tensor_distance_log_n: 3.6157
# Epoch 13/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.6056 - tensor_distance_log_n: 3.6056 - val_loss: 3.6155 - val_tensor_distance_log_n: 3.6155
# Epoch 14/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5915 - tensor_distance_log_n: 3.5915 - val_loss: 3.6197 - val_tensor_distance_log_n: 3.6197
# Epoch 15/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5894 - tensor_distance_log_n: 3.5894 - val_loss: 3.5993 - val_tensor_distance_log_n: 3.5993
# Epoch 16/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5681 - tensor_distance_log_n: 3.5681 - val_loss: 3.6083 - val_tensor_distance_log_n: 3.6083
# Epoch 17/30
# 80/80 [==============================] - 0s 4ms/step - loss: 3.5761 - tensor_distance_log_n: 3.5761 - val_loss: 3.5852 - val_tensor_distance_log_n: 3.5852
# Epoch 18/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5794 - tensor_distance_log_n: 3.5794 - val_loss: 3.6035 - val_tensor_distance_log_n: 3.6035
# Epoch 19/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5983 - tensor_distance_log_n: 3.5983 - val_loss: 3.5991 - val_tensor_distance_log_n: 3.5991
# Epoch 20/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5630 - tensor_distance_log_n: 3.5630 - val_loss: 3.5917 - val_tensor_distance_log_n: 3.5917
# Epoch 21/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5617 - tensor_distance_log_n: 3.5617 - val_loss: 3.6348 - val_tensor_distance_log_n: 3.6348
# Epoch 22/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5575 - tensor_distance_log_n: 3.5575 - val_loss: 3.6076 - val_tensor_distance_log_n: 3.6076
# Epoch 23/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5581 - tensor_distance_log_n: 3.5581 - val_loss: 3.6255 - val_tensor_distance_log_n: 3.6255
# Epoch 24/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5501 - tensor_distance_log_n: 3.5501 - val_loss: 3.5877 - val_tensor_distance_log_n: 3.5877
# Epoch 25/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5406 - tensor_distance_log_n: 3.5406 - val_loss: 3.6249 - val_tensor_distance_log_n: 3.6249
# Epoch 26/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5640 - tensor_distance_log_n: 3.5640 - val_loss: 3.6047 - val_tensor_distance_log_n: 3.6047
# Epoch 27/30
# 80/80 [==============================] - 0s 2ms/step - loss: 3.5346 - tensor_distance_log_n: 3.5346 - val_loss: 3.5840 - val_tensor_distance_log_n: 3.5840
# Epoch 28/30
# 80/80 [==============================] - 0s 4ms/step - loss: 3.5342 - tensor_distance_log_n: 3.5342 - val_loss: 3.6017 - val_tensor_distance_log_n: 3.6017
# Epoch 29/30
# 80/80 [==============================] - 0s 3ms/step - loss: 3.5336 - tensor_distance_log_n: 3.5336 - val_loss: 3.6536 - val_tensor_distance_log_n: 3.6536
# Epoch 30/30
# 80/80 [==============================] - 0s 4ms/step - loss: 3.5475 - tensor_distance_log_n: 3.5475 - val_loss: 3.6354 - val_tensor_distance_log_n: 3.6354

# %%
"""lstm_model.fit(x=conv_train[0],
           y=conv_train[1],
           batch_size=32,
           epochs=30,
           verbose=1,
           validation_data=conv_val
          )"""
"sob"
# Out:
# 'sob'

# %%
# predict center is 7500,7500 for each row
center_pred = tf.fill(test[1][1].shape,7500.)
center_error = float(metricli(center_pred, test[1][1]))

# %% [markdown]
# ## Evaluation

# %%
linear_error = linear.evaluate(test[1][0], test[1][1])
baseline_error = baseline.evaluate(test[1][0], test[1][1])
dense_error = dense.evaluate(test[1][0], test[1][1])
md_err = {}
conv_err = {}
for i in conv_models.keys():
    conv_err[i] = conv_models[i].evaluate(test[i][0], test[i][1])
    md_err[i] = multi_dense_models[i].evaluate(test[i][0], test[i][1])
    print("multistep dense model mae",str(i), md_err[i][1])
    print("convolutional model mae",str(i), conv_err[i][1])
print("baseline mae:", baseline_error[1])
print("center mae:", center_error)
print("linear mae:", linear_error[1])
print("dense mae:", dense_error[1])
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 3.6762 - tensor_distance_log_n: 3.6762
# 10/10 [==============================] - 0s 2ms/step - loss: 3.8455 - tensor_distance_log_n: 3.8455
# 10/10 [==============================] - 0s 3ms/step - loss: 3.7311 - tensor_distance_log_n: 3.7311
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6606 - tensor_distance_log_n: 3.6606
# 10/10 [==============================] - 0s 2ms/step - loss: 3.6068 - tensor_distance_log_n: 3.6068
# multistep dense model mae 2 3.60675311088562
# convolutional model mae 2 3.6606292724609375
# 10/10 [==============================] - 0s 2ms/step - loss: 3.6412 - tensor_distance_log_n: 3.6412
# 10/10 [==============================] - 0s 3ms/step - loss: 3.6268 - tensor_distance_log_n: 3.6268
# multistep dense model mae 3 3.626807689666748
# convolutional model mae 3 3.6412155628204346
# 10/10 [==============================] - 0s 777us/step - loss: 3.6549 - tensor_distance_log_n: 3.6549
# 10/10 [==============================] - 0s 1ms/step - loss: 3.6136 - tensor_distance_log_n: 3.6136
# multistep dense model mae 4 3.6136250495910645
# convolutional model mae 4 3.6549460887908936
# baseline mae: 3.8455264568328857
# center mae: 3.6526169776916504
# linear mae: 3.6761932373046875
# dense mae: 3.7310516834259033

# %% [markdown]
# ## Plotting model's predictions

# %%
# dense model
wide_window.plot_map2(dense,input_width=1,plot_col=["playerx","playery"])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1, 61) for input Tensor("dense_1_input_1:0", shape=(None, 1, 61), dtype=float32), but it was called on an input with incompatible shape (None, 61).

# %%
# lookback of 3
wide_window.plot_map2(conv_models[3],input_width=3,plot_col=["playerx","playery"])

# %%
# lookback of 4
wide_window.plot_map2(conv_models[4],input_width=4,plot_col=["playerx","playery"])

# %%
# lookback of 2
wide_window.plot_map2(conv_models[2],input_width=2,plot_col=["playerx","playery"])

# %%
# a small look at what a model is doing - I'd like to look more into this
import keras

# %%
keras.utils.plot_model(conv_models[2], "images/dense_model.png", show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-868b1d269d64> in <module>
# ----> 1 keras.utils.plot_model(conv_models[2], "images/dense_model.png", show_shapes=True)
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir, expand_nested, dpi)
#     314     extension = extension[1:]
#     315   # Save image to disk.
# --> 316   dot.write(to_file, format=extension)
#     317   # Return the image as a Jupyter Image object, to be displayed in-line.
#     318   # Note that we cannot easily detect whether the code is running in a
#
# /opt/anaconda3/lib/python3.7/site-packages/pydotplus/graphviz.py in write(self, path, prog, format)
#    1892             prog = self.prog
#    1893
# -> 1894         fobj, close = get_fobj(path, 'w+b')
#    1895         try:
#    1896             if format == 'raw':
#
# /opt/anaconda3/lib/python3.7/site-packages/pydotplus/graphviz.py in get_fobj(fname, mode)
#     148     """
#     149     if is_string_like(fname):
# --> 150         fobj = open(fname, mode)
#     151         close = True
#     152     elif hasattr(fname, 'write'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/dense_model.png'
